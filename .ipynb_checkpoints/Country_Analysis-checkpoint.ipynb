# %%
#Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#File Location
csvfile = "Output/Resources/wine_data.csv"
#Read csv file and store in Pandas dataframe, preview head (skipfirst colmn)
wine_data_raw = pd.read_csv(csvfile,usecols=range(1,14))
wine_data_raw.head()
# Out:
#     country                                        description  \
# 0  Portugal  This is ripe and fruity, a wine that is smooth...
# 1        US  Tart and snappy, the flavors of lime flesh and...
# 2        US  Pineapple rind, lemon pith and orange blossom ...
# 3        US  Much like the regular bottling from 2012, this...
# 4     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 0                            Avidagos      87   15.0           Douro
# 1                                 NaN      87   14.0          Oregon
# 2                Reserve Late Harvest      87   13.0        Michigan
# 3  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 4                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# 0                  NaN                NaN          Roger Voss
# 1    Willamette Valley  Willamette Valley        Paul Gregutt
# 2  Lake Michigan Shore                NaN  Alexander Peartree
# 3    Willamette Valley  Willamette Valley        Paul Gregutt
# 4              Navarra                NaN   Michael Schachner
#
#   taster_twitter_handle                                              title  \
# 0            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 1           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 2                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 3           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 4           @wineschach  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#               variety               winery
# 0      Portuguese Red  Quinta dos Avidagos
# 1          Pinot Gris            Rainstorm
# 2            Riesling           St. Julian
# 3          Pinot Noir         Sweet Cheeks
# 4  Tempranillo-Merlot               Tandem

# %%
wine_data_raw.count()
# Out:
# country                  120916
# description              120975
# designation               86196
# points                   120975
# price                    120975
# province                 120916
# region_1                 101400
# region_2                  50292
# taster_name               96479
# taster_twitter_handle     91559
# title                    120975
# variety                  120974
# winery                   120975
# dtype: int64

# %%
# Consolidating to a smaller DataFrame
wine_data_df = pd.DataFrame({"Country" : wine_data_raw["country"], "Region" : wine_data_raw["province"], 
                             "Price_per_Bottle" : wine_data_raw["price"], "Wineries" : wine_data_raw["winery"]})

wine_data_df.head()
# Out:
#     Country          Region  Price_per_Bottle             Wineries
# 0  Portugal           Douro              15.0  Quinta dos Avidagos
# 1        US          Oregon              14.0            Rainstorm
# 2        US        Michigan              13.0           St. Julian
# 3        US          Oregon              65.0         Sweet Cheeks
# 4     Spain  Northern Spain              15.0               Tandem

# %%
# Grouping countries into Other with less than 1000 wines per country
ratings = []
for country in wine_data_df["Country"]:
    if country == "US":
        ratings.append("US")
    elif country == "France":
        ratings.append("France")
    elif country == "Italy":
        ratings.append("Italy")
    elif country == "Spain":
        ratings.append("Spain")
    elif country == "Portugal":
        ratings.append("Portugal") 
    elif country == "Chile":
        ratings.append("Chile") 
    elif country == "Argentina":
        ratings.append("Argentina") 
    elif country == "Austria":
        ratings.append("Austria") 
    elif country == "Australia":
        ratings.append("Australia") 
    elif country == "Germany":
        ratings.append("Germany") 
    elif country == "New Zealand":
        ratings.append("New Zealand") 
    elif country == "South Africa":
        ratings.append("South Africa") 
    else:
         ratings.append("Other")

# Adding new column    
wine_data_df["New Country"] = ratings
wine_data_df
# Out:
#             Country             Region  Price_per_Bottle  \
# 0          Portugal              Douro              15.0
# 1                US             Oregon              14.0
# 2                US           Michigan              13.0
# 3                US             Oregon              65.0
# 4             Spain     Northern Spain              15.0
# 5             Italy  Sicily & Sardinia              16.0
# 6            France             Alsace              24.0
# 7           Germany        Rheinhessen              12.0
# 8            France             Alsace              27.0
# 9                US         California              19.0
# 10           France             Alsace              30.0
# 11               US         California              34.0
# 12               US         California              12.0
# 13          Germany              Mosel              24.0
# 14        Argentina              Other              30.0
# 15        Argentina   Mendoza Province              13.0
# 16            Spain     Northern Spain              28.0
# 17               US           Virginia              32.0
# 18               US           Virginia              23.0
# 19               US             Oregon              20.0
# 20            Italy  Sicily & Sardinia              19.0
# 21               US         California              22.0
# 22            Italy  Sicily & Sardinia              35.0
# 23               US         California              69.0
# 24            Italy  Sicily & Sardinia              13.0
# 25            Italy  Sicily & Sardinia              10.0
# 26            Italy  Sicily & Sardinia              17.0
# 27               US         California              16.0
# 28               US         California              50.0
# 29               US         California              20.0
# ...             ...                ...               ...
# 120945           US         California              36.0
# 120946           US         California              20.0
# 120947           US         California              35.0
# 120948        Italy  Sicily & Sardinia              29.0
# 120949       Israel            Galilee              25.0
# 120950           US         California              20.0
# 120951      Germany              Mosel              17.0
# 120952        Italy  Sicily & Sardinia              20.0
# 120953    Argentina              Other              43.0
# 120954           US         California              35.0
# 120955           US         California              35.0
# 120956       France             Alsace              30.0
# 120957           US         California              22.0
# 120958  New Zealand        Hawke's Bay              25.0
# 120959  New Zealand        Marlborough              15.0
# 120960  New Zealand        Marlborough              40.0
# 120961  New Zealand        Hawke's Bay              19.0
# 120962        Spain     Northern Spain              17.0
# 120963  New Zealand        Hawke's Bay              35.0
# 120964       France             Alsace              57.0
# 120965     Portugal              Douro              48.0
# 120966        Italy  Sicily & Sardinia              30.0
# 120967        Italy  Sicily & Sardinia              40.0
# 120968       Israel            Galilee              20.0
# 120969       France             Alsace              28.0
# 120970      Germany              Mosel              28.0
# 120971           US             Oregon              75.0
# 120972       France             Alsace              30.0
# 120973       France             Alsace              32.0
# 120974       France             Alsace              21.0
#
#                                         Wineries  New Country
# 0                            Quinta dos Avidagos     Portugal
# 1                                      Rainstorm           US
# 2                                     St. Julian           US
# 3                                   Sweet Cheeks           US
# 4                                         Tandem        Spain
# 5                                Terre di Giurfo        Italy
# 6                                       Trimbach       France
# 7                                    Heinz Eifel      Germany
# 8                             Jean-Baptiste Adam       France
# 9                             Kirkland Signature           US
# 10                                    Leon Beyer       France
# 11                              Louis M. Martini           US
# 12                                      Mirassou           US
# 13                               Richard Böcking      Germany
# 14                                 Felix Lavaque    Argentina
# 15                                 Gaucho Andino    Argentina
# 16                                      Pradorey        Spain
# 17                                   Quiévremont           US
# 18                                   Quiévremont           US
# 19                                       Acrobat           US
# 20                            Baglio di Pianetto        Italy
# 21                                       Bianchi           US
# 22                                     Canicattì        Italy
# 23                           Castello di Amorosa           US
# 24                                      Stemmari        Italy
# 25                                      Stemmari        Italy
# 26                               Terre di Giurfo        Italy
# 27                       Clarksburg Wine Company           US
# 28                                       Envolve           US
# 29                                       Envolve           US
# ...                                          ...          ...
# 120945                                  Standish           US
# 120946                                   Apriori           US
# 120947                                  Arrowood           US
# 120948           Baglio del Cristo di Campobello        Italy
# 120949                                    Barkan        Other
# 120950                                 Birichino           US
# 120951              Bischöfliche Weingüter Trier      Germany
# 120952                  Feudo Principi di Butera        Italy
# 120953                           Finca Las Moras    Argentina
# 120954                             Flora Springs           US
# 120955                                    Hendry           US
# 120956                         Henri Schoenheitz       France
# 120957                                   Houdini           US
# 120958                                Mills Reef  New Zealand
# 120959                                       Ara  New Zealand
# 120960                                 Dog Point  New Zealand
# 120961                                Esk Valley  New Zealand
# 120962                        Viñedos Real Rubio        Spain
# 120963                                    Babich  New Zealand
# 120964                         Cave de Turckheim       France
# 120965                       Caves Transmontanas     Portugal
# 120966                                       COS        Italy
# 120967                                  Cusumano        Italy
# 120968                                    Dalton        Other
# 120969                   Domaine Rieflé-Landmann       France
# 120970  Dr. H. Thanisch (Erben Müller-Burggraef)      Germany
# 120971                                  Citation           US
# 120972                           Domaine Gresser       France
# 120973                      Domaine Marcel Deiss       France
# 120974                          Domaine Schoffit       France
#
# [120975 rows x 5 columns]

# %%
# Grouping by New Country and calculating based on New Country
wine_data_country = wine_data_df.groupby("New Country")
wine_data_country_count = wine_data_country["New Country"].count()
wine_data_country_wineries_count = wine_data_country["Wineries"].nunique()
wine_data_country_region_count = wine_data_country["Region"].nunique()
wine_data_country_mean = wine_data_country["Price_per_Bottle"].mean()
wine_data_country_high = wine_data_country["Price_per_Bottle"].max()
wine_data_country_low = wine_data_country["Price_per_Bottle"].min()
Wines_per_Winery = wine_data_country_count / wine_data_country_wineries_count

# %%
# Creating Dataframe by New Country
wine_data_country_df = pd.DataFrame({ "# of Wines per Country" : wine_data_country_count, "# of Wineries per Country" : wine_data_country_wineries_count,
                                     "Wines per Winery": Wines_per_Winery, "# of Regions per Country" : wine_data_country_region_count,
                                     "Average Price" : wine_data_country_mean, "Highest Price" : wine_data_country_high,
                                    "Lowest Price" : wine_data_country_low})
wine_data_country_df_sort = wine_data_country_df.sort_values(["# of Wines per Country"], ascending=False)
wine_data_country_df_sort
# Out:
#               # of Wines per Country  # of Wineries per Country  \
# New Country
# US                             54265                       5368
# France                         17776                       3400
# Italy                          16914                       2629
# Spain                           6573                       1428
# Portugal                        4875                        382
# Chile                           4416                        314
# Argentina                       3756                        528
# Austria                         2799                        211
# Other                           2516                        502
# Australia                       2294                        467
# Germany                         2120                        250
# New Zealand                     1378                        286
# South Africa                    1293                        273
#
#               Wines per Winery  # of Regions per Country  Average Price  \
# New Country
# US                   10.108979                        27      36.573464
# France                5.228235                        11      41.139120
# Italy                 6.433625                        10      39.663770
# Spain                 4.602941                         8      28.215275
# Portugal             12.761780                        40      26.218256
# Chile                14.063694                        43      20.786458
# Argentina             7.113636                         2      24.510117
# Austria              13.265403                        25      30.762772
# Other                 5.011952                       178      27.084658
# Australia             4.912206                         6      35.437663
# Germany               8.480000                        13      42.257547
# New Zealand           4.818182                        19      26.931785
# South Africa          4.736264                        40      24.668987
#
#               Highest Price  Lowest Price
# New Country
# US                   2013.0           4.0
# France               3300.0           5.0
# Italy                 900.0           5.0
# Spain                 770.0           4.0
# Portugal             1000.0           5.0
# Chile                 400.0           5.0
# Argentina             230.0           4.0
# Austria              1100.0           7.0
# Other                 764.0           4.0
# Australia             850.0           5.0
# Germany               775.0           5.0
# New Zealand           130.0           7.0
# South Africa          330.0           5.0

# %%
# Set plot style
plt.style.use('fivethirtyeight')

# Bar Chart based on # of Wines per Country
wine_data_country_df_sort["# of Wines per Country"].plot(kind="bar", grid = True, fontsize = 25, figsize=(25,10))
plt.title("# of Wines per Country")
plt.ylabel("Number of Wines")
plt.xlabel("Country")
plt.tight_layout()
plt.savefig("Output/#ofWinesperCountry.png")
plt.show()

# %%
# Set plot style
plt.style.use('fivethirtyeight')

# Bar Chart based on # of Wineries per Country
wine_data_country_wineries_df_sort = wine_data_country_df.sort_values(["# of Wineries per Country"], ascending=False)
wine_data_country_wineries_df_sort["# of Wineries per Country"].plot(kind="bar", grid = True, fontsize = 25, figsize=(25,10))
plt.title("# of Wineries per Country")
plt.ylabel("Number of Wineries")
plt.xlabel("Country")
plt.tight_layout()
plt.savefig("Output/#ofWineriesperCountry.png")
plt.show()

# %%
# Set plot style
plt.style.use('fivethirtyeight')

# Bar Chart based on Average Price per Country
wine_data_country_AvgPrice_df_sort = wine_data_country_df.sort_values(["Average Price"], ascending=False)
wine_data_country_AvgPrice_df_sort["Average Price"].plot(kind="bar", grid = True, fontsize = 25, figsize=(25,10))
plt.title("Average Price by Country")
plt.xlabel("Country")
plt.ylabel("Average Price ($)")
plt.tight_layout()
plt.savefig("Output/AveragePriceperCountry.png")

plt.show()

# %%
# Creating table summary of Country data
wine_data_country_df_sort["Average Price"] = wine_data_country_df_sort["Average Price"].map("${:.0f}".format)
wine_data_country_df_sort["Highest Price"] = wine_data_country_df_sort["Highest Price"].map("${:.0f}".format)
wine_data_country_df_sort["Lowest Price"] = wine_data_country_df_sort["Lowest Price"].map("${:.0f}".format)
wine_data_country_df_sort["Wines per Winery"] = wine_data_country_df_sort["Wines per Winery"].map("{:.0f}".format)
wine_data_country_df_sort["# of Wines per Country"] = wine_data_country_df_sort["# of Wines per Country"].map("{:,}".format)
plt.savefig("Output/Countrytable.png")
wine_data_country_df_sort
# Out:
#              # of Wines per Country  # of Wineries per Country  \
# New Country
# US                           54,265                       5368
# France                       17,776                       3400
# Italy                        16,914                       2629
# Spain                         6,573                       1428
# Portugal                      4,875                        382
# Chile                         4,416                        314
# Argentina                     3,756                        528
# Austria                       2,799                        211
# Other                         2,516                        502
# Australia                     2,294                        467
# Germany                       2,120                        250
# New Zealand                   1,378                        286
# South Africa                  1,293                        273
#
#              Wines per Winery  # of Regions per Country Average Price  \
# New Country
# US                         10                        27           $37
# France                      5                        11           $41
# Italy                       6                        10           $40
# Spain                       5                         8           $28
# Portugal                   13                        40           $26
# Chile                      14                        43           $21
# Argentina                   7                         2           $25
# Austria                    13                        25           $31
# Other                       5                       178           $27
# Australia                   5                         6           $35
# Germany                     8                        13           $42
# New Zealand                 5                        19           $27
# South Africa                5                        40           $25
#
#              Highest Price Lowest Price
# New Country
# US                   $2013           $4
# France               $3300           $5
# Italy                 $900           $5
# Spain                 $770           $4
# Portugal             $1000           $5
# Chile                 $400           $5
# Argentina             $230           $4
# Austria              $1100           $7
# Other                 $764           $4
# Australia             $850           $5
# Germany               $775           $5
# New Zealand           $130           $7
# South Africa          $330           $5

# %%
wine_data_country_df_sort.to_excel("Output/CountryAnalysis.xlsx")

# %% [markdown]
# Start calculating by region

# %%
# Bringing consolidating Dataframe
wine_data_df2 = wine_data_df   
wine_data_df2.head(5)
# Out:
#     Country          Region  Price_per_Bottle             Wineries New Country
# 0  Portugal           Douro              15.0  Quinta dos Avidagos    Portugal
# 1        US          Oregon              14.0            Rainstorm          US
# 2        US        Michigan              13.0           St. Julian          US
# 3        US          Oregon              65.0         Sweet Cheeks          US
# 4     Spain  Northern Spain              15.0               Tandem       Spain

# %%
#Calculating new columns for Regions Data
Wine_region = wine_data_df2.groupby(["Region","New Country"])
Wine_region_count = Wine_region["Region"].count()
Wine_region_wineries_count = Wine_region["Wineries"].nunique()
Wine_region_mean = Wine_region["Price_per_Bottle"].mean()
Wine_region_max = Wine_region["Price_per_Bottle"].max()
Wine_region_min = Wine_region["Price_per_Bottle"].min()

# %%
# Building regions Dataframe
wine_region_df = pd.DataFrame({"# of Wines per Region" : Wine_region_count, "# of Wineries per Region" : Wine_region_wineries_count,
                               "Average Price" : Wine_region_mean,"Highest Price" : Wine_region_max,
                               "Lowest Price" : Wine_region_min, })
wine_region_df_sort = wine_region_df.sort_values(["# of Wines per Region"], ascending=False)
wine_region_df_sort.head(10)
# Out:
#                               # of Wines per Region  # of Wineries per Region  \
# Region           New Country
# California       US                           36104                      3929
# Washington       US                            8583                       654
# Oregon           US                            5359                       510
# Tuscany          Italy                         5128                       825
# Bordeaux         France                        4002                      1425
# Northern Spain   Spain                         3797                       803
# Mendoza Province Argentina                     3226                       453
# Burgundy         France                        3106                       332
# Piedmont         Italy                         3089                       463
# New York         US                            2676                       169
#
#                               Average Price  Highest Price  Lowest Price
# Region           New Country
# California       US               39.041048         2013.0           4.0
# Washington       US               32.436444          240.0           6.0
# Oregon           US               36.545064          275.0           5.0
# Tuscany          Italy            47.683697          900.0           6.0
# Bordeaux         France           38.911794         3300.0           6.0
# Northern Spain   Spain            30.771925          600.0           5.0
# Mendoza Province Argentina        25.053317          230.0           4.0
# Burgundy         France           71.058274         2500.0           9.0
# Piedmont         Italy            54.957268          595.0           7.0
# New York         US               22.826233          125.0           7.0

# %%
# Set plot style
plt.style.use('fivethirtyeight')

# Bar chart for # of wines per region
wine_region_df_sort["# of Wines per Region"].head(10).plot(kind="bar", fontsize = 20, figsize=(25,10))
plt.title("# of Wines per Region (Top 10)")
plt.xlabel("Region")
plt.ylabel("# of Wines")
plt.tight_layout()
plt.savefig("Output/#ofWinesperRegion.png")

plt.show()

# %%
# Set plot style
plt.style.use('fivethirtyeight')

# Bar chart for # of wineries per region
wine_region_df_wineries_sort = wine_region_df.sort_values(["# of Wineries per Region"], ascending=False)
wine_region_df_wineries_sort["# of Wineries per Region"].head(10).plot(kind="bar",fontsize = 20, figsize=(25,10))
plt.title("# of Wineries per Region (Top 10)")
plt.xlabel("Region")
plt.ylabel("# of Wineries")
plt.tight_layout()
plt.savefig("Output/#ofWineriesperregion.png")
plt.show()

# %%
# Set plot style
plt.style.use('fivethirtyeight')

# Bar chart for Average Price per region
wine_region_df_AvgPrice_sort = wine_region_df.sort_values(["Average Price"], ascending=False)
wine_region_df_AvgPrice_sort["Average Price"].head(10).plot(kind="bar", fontsize = 18, figsize=(25,10))
plt.title("Average Price per Region (Top 10)")
plt.xlabel("Region")
plt.ylabel("Average Price ($)")
plt.tight_layout()
plt.savefig("Output/topAveragePriceperRegion.png")
plt.show()

# %%
# Set plot style
plt.style.use('fivethirtyeight')

# Bar chart for Average Price per region
wine_region_df_AvgPrice_sort = wine_region_df.sort_values(["Average Price"], ascending=True)
wine_region_df_AvgPrice_sort["Average Price"].head(10).plot(kind="bar", fontsize = 20, figsize=(25,10))
plt.title("Average Price per Region (Bottom 10)")
plt.xlabel("Region")
plt.ylabel("Average Price ($)")
plt.tight_layout()
plt.savefig("Output/bottomAveragePriceperRegion.png")
plt.show()

# %%
wine_region_df_sort["Average Price"] = wine_region_df_sort["Average Price"].map("${:.0f}".format)
wine_region_df_sort["Highest Price"] = wine_region_df_sort["Highest Price"].map("${:.0f}".format)
wine_region_df_sort["Lowest Price"] = wine_region_df_sort["Lowest Price"].map("${:.0f}".format)
wine_region_df_sort["# of Wineries per Region"] = wine_region_df_sort["# of Wineries per Region"].map("{:,}".format)
wine_region_df_sort["# of Wines per Region"] = wine_region_df_sort["# of Wines per Region"].map("{:,}".format)
plt.savefig("Output/Countrytable.png")
wine_region_df_sort.head(10)
# Out:
#                              # of Wines per Region # of Wineries per Region  \
# Region           New Country
# California       US                         36,104                    3,929
# Washington       US                          8,583                      654
# Oregon           US                          5,359                      510
# Tuscany          Italy                       5,128                      825
# Bordeaux         France                      4,002                    1,425
# Northern Spain   Spain                       3,797                      803
# Mendoza Province Argentina                   3,226                      453
# Burgundy         France                      3,106                      332
# Piedmont         Italy                       3,089                      463
# New York         US                          2,676                      169
#
#                              Average Price Highest Price Lowest Price
# Region           New Country
# California       US                    $39         $2013           $4
# Washington       US                    $32          $240           $6
# Oregon           US                    $37          $275           $5
# Tuscany          Italy                 $48          $900           $6
# Bordeaux         France                $39         $3300           $6
# Northern Spain   Spain                 $31          $600           $5
# Mendoza Province Argentina             $25          $230           $4
# Burgundy         France                $71         $2500           $9
# Piedmont         Italy                 $55          $595           $7
# New York         US                    $23          $125           $7

# %%
wine_region_df_sort.to_excel("Output/RegionAnalysis.xlsx")
